# %%
# so a link contains a storage half and another half that tells if it has another link connected to it
# storage half (
# next link half )
# together they amke one link
# ()
class link:
    def __init__(self, storage):
        self.storage = storage
        self.nextlink = None
        
# a chain can have no links
# this is an intangible chain you cant pick it up it has no links
# you can add to this chain
# if the chain is linkless it now has 1 chain
# again a chain has two halves to make a link
# a link contains a storage quantity its other half tells if another link is connected to it
# if no link is connected to it the nextlink container of the link is None
# if the link is connected to another link its nextlink contains the literal link that it is connected to
# only the end chain has a nextlink of None
# if the chain is only 1 link long then the first link and the last link are the same and it has a nextlink value of None
# after its storage value of (whatever variable data its holding)
# to add to the chain we have to set its first length if the chain has no lenghts 
# to add to a chain with links we find the end link and change its None value to be the chain object of the data we are adding to our list
# its essentially a growing firstlink.next.next.next.next.next.next.storage call to get your data
# the number of .next jumps indicates the index of the value in your chain at that link
# again chains need a storage half and a nextlink half
# a link
# so what makes up a link
# first half of link [storage(whatever you are saving to your list
# second half of link literally the next link object]
# the exclusion of this is if the chain has only 1 length and the end link
# if a chain only has one link then it is unlinked but still a chain
# unlinked being it has None as its nextlink and not another link as its nextlink
# the end link will always have None as its nextlink value
# all other links will have the next link as its nextink value

class chain:
    def __init__(self):
        self.firstlink = None

    def addlink(self, storage):
        # if chain has no links add
        if self.firstlink == None:
            # create new storage chain link
            newlink = link(storage)
            self.firstlink = newlink
        # if chain has links we bind to end
        else:
            # we dont know end link
            end_link = None
            # search for end link by starting at first
            checklink = self.firstlink
            
            # go until .nextlink==None
            go = True
            while go:
                if checklink.nextlink == None:
                    end_link = checklink
                    go = False
                else:
                    checklink = checklink.nextlink
            end_link.nextlink = link(storage)

    def print_chain(self):
        go = True
        # start at first link
        currentlink = self.firstlink

        while go:
            print(currentlink.storage)
            if currentlink.nextlink is not None:
                currentlink = currentlink.nextlink
            else:
                go = False
            
        

chain1 = chain()
chain1.addlink("hello")
chain1.addlink(1)
chain1.addlink(1)
chain1.print_chain()

chain2 = chain()
chain2.addlink("im only 1 link chain!")
print()
chain2.print_chain()

chain3= chain()
chain3.addlink(chain1)
chain3.addlink(c

         
print()
chain3.print_chain()
# Out:
# hello
# 1
# 1
#
# im only 1 link chain!
#
# ...

# %%
chain1.firstlink.nextlink
